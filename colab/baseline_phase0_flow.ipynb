# %% [markdown]
# # Phase 0 Baseline Notebook Index
#
# Phase 0 기준점 모델은 실험 조합별 독립 노트북에서 실행합니다. 각 노트북은 하나의 고정 config만 실행하므로 `SESSION_ID`나 선택형 파라미터가 필요 없습니다.
#
# ## Fixed Baseline Notebooks
#
# - `colab/baselines/tcn_raw_baseline.ipynb` → `B-TCN-raw`
# - `colab/baselines/tcn_filtered_baseline.ipynb` → `B-TCN-D`
# - `colab/baselines/gru_raw_baseline.ipynb` → `B-GRU-raw`
# - `colab/baselines/gru_filtered_baseline.ipynb` → `B-GRU-D`
#
# 산출물은 `results/baselines_phase0/{experiment_id}/`에 저장됩니다.
