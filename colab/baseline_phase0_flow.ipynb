# %% [markdown]
# # Baseline Notebook Index
#
# 모델별 실험은 아래 전용 노트북에서 실행합니다.
#
# - `colab/tcn_baseline_session.ipynb`: TCN 전용 공유 세션 노트북
# - `colab/gru_baseline_session.ipynb`: GRU 전용 공유 세션 노트북
#
# 각 인원은 전용 노트북에서 `SESSION_ID`를 다르게 지정하고, 같은 Google Drive 공유 폴더 아래 `results/shared_sessions/{model}/{SESSION_ID}/`에 산출물을 남깁니다.
